# %% [markdown]
# # Taller integrador

# %%
# instalmos la libreria de pandas
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#importamos pandas y le ponemos el sobrenobre "pd"
import pandas as pd 
#con este codigo imprimimos la version del pandas
print(pd.__version__)
#metemos en la variable df es docuemnto de estudiantes
df = pd.read_csv("estudiantes.csv")
df
# Out:
# 2.2.2
#     id            nombre  edad        ciudad  cursos_previos  promedio  activo
# 0    1       Laura Gómez    42      Medellín               0       8.3    True
# 1    2      Carlos Pérez    29          Cali               1       7.9    True
# 2    3        Anita Ruiz    40       Pereira               0       3.7    True
# 3    4       Juan Torres    29        Bogotá               8       4.8   False
# 4    5       María López    29     Manizales               4       8.8    True
# 5    6     Andrés Castro    27       Pereira               5       5.3    True
# 6    7     Sofía Herrera    32      Medellín               1       6.0    True
# 7    8    Diego Martínez    33     Cartagena               0       8.2    True
# 8    9    Valentina Ríos    34      Medellín               8       5.4    True
# 9   10       Felipe Mora    40  Barranquilla               1       3.8    True
# 10  11     Camila Vargas    31      Medellín               3       9.1   False
# ...

# %%
# numero listas y de columnas que hay 
print(df.shape)
# nombre exacto de las columnas
print(df.columns.tolist())
# Out:
# (20, 7)
# ['id', 'nombre', 'edad', 'ciudad', 'cursos_previos', 'promedio', 'activo']

# %%
# imprime todos las filas de la columna nombre
df["nombre"]
# Out:
# 0          Laura Gómez
# 1         Carlos Pérez
# 2           Anita Ruiz
# 3          Juan Torres
# 4          María López
# 5        Andrés Castro
# 6        Sofía Herrera
# 7       Diego Martínez
# 8       Valentina Ríos
# 9          Felipe Mora
# 10       Camila Vargas
# 11      Sebastián Díaz
# 12    Isabella Ramírez
# 13        Mateo Suárez
# 14     Lucía Fernández
# 15       Daniel Ortega
# 16    Gabriela Mendoza
# 17    Alejandro Flores
# 18       Natalia Reyes
# 19       Ricardo Rojas
# Name: nombre, dtype: object

# %%
# para leer la fila y la columna (primero la fila y despues el nombre de la columna)
print(df.loc[0, "nombre"])
print(df.loc[3, "promedio"])
# Out:
# Laura Gómez
# 4.8

# %%
# mostrar los primero registros para orientarme en la data
df.head(5)
# Out:
#    id        nombre  edad     ciudad  cursos_previos  promedio  activo
# 0   1   Laura Gómez    42   Medellín               0       8.3    True
# 1   2  Carlos Pérez    29       Cali               1       7.9    True
# 2   3    Anita Ruiz    40    Pereira               0       3.7    True
# 3   4   Juan Torres    29     Bogotá               8       4.8   False
# 4   5   María López    29  Manizales               4       8.8    True

# %%
""" para describir las estadisticas del df
count - cuantos valores hay en la columna
mean - promedio de todos los valores (media)
std - desviacion estandarde (cuando es alto es porque los valores estan muy dispersos)
min - valor minimo 
max - valor maximo 
"""
df.describe()
# Out:
#              id       edad  cursos_previos   promedio
# count  20.00000  20.000000       20.000000  20.000000
# mean   10.50000  34.100000        3.100000   6.705000
# std     5.91608   5.901828        2.531902   1.814409
# min     1.00000  27.000000        0.000000   3.700000
# 25%     5.75000  29.000000        1.000000   5.275000
# 50%    10.50000  32.500000        2.500000   6.650000
# 75%    15.25000  40.000000        5.000000   8.225000
# max    20.00000  45.000000        8.000000   9.300000

# %%
# traer quienes tiene el promedio por arriba de 8
df[df["promedio"] >= 8.0]
# Out:
#     id           nombre  edad        ciudad  cursos_previos  promedio  activo
# 0    1      Laura Gómez    42      Medellín               0       8.3    True
# 4    5      María López    29     Manizales               4       8.8    True
# 7    8   Diego Martínez    33     Cartagena               0       8.2    True
# 10  11    Camila Vargas    31      Medellín               3       9.1   False
# 14  15  Lucía Fernández    42  Barranquilla               5       9.0    True
# 18  19    Natalia Reyes    45     Cartagena               6       9.3   False

# %%
# saber los que tienen promedio mayor o igual a 8 y que esten activos
df[(df["promedio"] >= 8.0) & (df["activo"]==True)]
# Out:
#     id           nombre  edad        ciudad  cursos_previos  promedio  activo
# 0    1      Laura Gómez    42      Medellín               0       8.3    True
# 4    5      María López    29     Manizales               4       8.8    True
# 7    8   Diego Martínez    33     Cartagena               0       8.2    True
# 14  15  Lucía Fernández    42  Barranquilla               5       9.0    True

# %%
# saber los que tienen promedio mayor o igual a 8 o que esten activos
df[(df["promedio"] >= 8.0) | (df["activo"]==True)]
# Out:
#     id            nombre  edad        ciudad  cursos_previos  promedio  activo
# 0    1       Laura Gómez    42      Medellín               0       8.3    True
# 1    2      Carlos Pérez    29          Cali               1       7.9    True
# 2    3        Anita Ruiz    40       Pereira               0       3.7    True
# 4    5       María López    29     Manizales               4       8.8    True
# 5    6     Andrés Castro    27       Pereira               5       5.3    True
# 6    7     Sofía Herrera    32      Medellín               1       6.0    True
# 7    8    Diego Martínez    33     Cartagena               0       8.2    True
# 8    9    Valentina Ríos    34      Medellín               8       5.4    True
# 9   10       Felipe Mora    40  Barranquilla               1       3.8    True
# 10  11     Camila Vargas    31      Medellín               3       9.1   False
# 11  12    Sebastián Díaz    30     Manizales               5       4.6    True
# ...

# %%
# ordenar los datos de forma ascendente
df[(df["promedio"]>=8.0)&(df["activo"]==True)].sort_values(by="edad", ascending=False)
# Out:
#     id           nombre  edad        ciudad  cursos_previos  promedio  activo
# 0    1      Laura Gómez    42      Medellín               0       8.3    True
# 14  15  Lucía Fernández    42  Barranquilla               5       9.0    True
# 7    8   Diego Martínez    33     Cartagena               0       8.2    True
# 4    5      María López    29     Manizales               4       8.8    True

# %% [markdown]
# ## Limpiar dataSet con criterio

# %%
# para llamar a los metodos siempre colocar parentesis 
df.isnull().sum()
# Out:
# id                0
# nombre            0
# edad              0
# ciudad            0
# cursos_previos    0
# promedio          0
# activo            0
# dtype: int64

# %%
df1 = pd.read_csv("estudiantes_ml_2026_.csv")
df1
# Out:
#                nombre  edad            ciudad       pais genero nivel_previo  \
# 0    Valentina Torres    28            Bogotá   Colombia      F   intermedio
# 1      Carlos Mendoza    34  Ciudad de México     México      M       básico
# 2          Anita Ruiz    25          Medellín   Colombia      F       básico
# 3       Jorge Ramírez    41              Lima       Perú      M     avanzado
# 4        Daniela Soto    29          Santiago      Chile      F   intermedio
# 5       Miguel Flores    37       Guadalajara     México      M       básico
# 6         Laura Gómez    31              Cali   Colombia      F       básico
# 7    Sebastián Castro    26      Buenos Aires  Argentina      M   intermedio
# 8       Camila Vargas    33             Quito    Ecuador      F       básico
# 9      Andrés Herrera    45      Barranquilla   Colombia      M     avanzado
# 10      Paula Jiménez    27        Montevideo    Uruguay      F       básico
# ...

# %%
df1.isnull().sum()
# Out:
# nombre                  0
# edad                    0
# ciudad                  0
# pais                    0
# genero                  0
# nivel_previo            0
# horas_estudio_semana    0
# promedio                2
# modulos_completados     0
# activo                  0
# fecha_ingreso           0
# trabaja_actualmente     0
# salario_usd             0
# objetivo                0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   nombre                25 non-null     object
#  1   edad                  25 non-null     int64
#  2   ciudad                25 non-null     object
#  3   pais                  25 non-null     object
#  4   genero                25 non-null     object
#  5   nivel_previo          25 non-null     object
#  6   horas_estudio_semana  25 non-null     int64
#  7   promedio              23 non-null     float64
#  8   modulos_completados   25 non-null     int64
#  9   activo                25 non-null     bool
#  10  fecha_ingreso         25 non-null     object
#  11  trabaja_actualmente   25 non-null     bool
#  12  salario_usd           25 non-null     int64
#  13  objetivo              25 non-null     object
# dtypes: bool(2), float64(1), int64(4), object(7)
# ...

# %% [markdown]
# pandas - libreria de python
# DataFrame - estructura que crea pandas cuando se carga un csv. Tiene por lo general filas y columnas
